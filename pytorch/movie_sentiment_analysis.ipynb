# %%
from torchtext.datasets import IMDB
import torch

# %%
train_dataset = IMDB(split="train")
test_dataset = IMDB(split="test")
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/datapipes/utils/common.py:24: UserWarning: Lambda function is not supported for pickle, please use regular python function or functools.partial instead.
#   warnings.warn(
# /opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/datapipes/iter/selecting.py:54: UserWarning: Lambda function is not supported for pickle, please use regular python function or functools.partial instead.
#   warnings.warn("Lambda function is not supported for pickle, please use "

# %%
train_dataset

# %%
"""
split training dataset into separate training and validation partitions
identify unique words in the training dataset
Map each unique word to a unique integer and encode the review text into encoded integers
Divide dataset into mini-batches as input to the model
"""
# Out:
# '\nsplit training dataset into separate training and validation partitions\nidentify unique words in the training dataset\nMap each unique word to a unique integer and encode the review text into encoded integers\nDivide dataset into mini-batches as input to the model\n'

# %%
#step 1: create the datasets

from torch.utils.data.dataset import random_split
torch.manual_seed(1)
train_dataset, valid_dataset = random_split(
    list(train_dataset), [20000,5000]
)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-190d7105d072> in <module>
#       4 torch.manual_seed(1)
#       5 train_dataset, valid_dataset = random_split(
# ----> 6     list(train_dataset), [20000,5000]
#       7 )
#
# /opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/_typing.py in wrap_generator(*args, **kwargs)
#     364             try:
#     365                 with context():
# --> 366                     response = gen.send(None)
#     367                 while True:
#     368                     request = yield response
#
# /opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/datapipes/iter/callable.py in __iter__(self)
#     110
#     111     def __iter__(self) -> Iterator[T_co]:
# --> 112         for data in self.datapipe:
#     113             yield self._apply_fn(data)
#     114
#
# /opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/_typing.py in wrap_generator(*args, **kwargs)
#     364             try:
#     365                 with context():
# --> 366                     response = gen.send(None)
#     367                 while True:
#     368                     request = yield response
#
# /opt/anaconda3/lib/python3.8/site-packages/torchdata/datapipes/iter/util/plain_text_reader.py in __iter__(self)
#     114
#     115     def __iter__(self) -> Iterator[Union[Str_Or_Bytes, Tuple[str, Str_Or_Bytes]]]:
# --> 116         for path, file in self.source_datapipe:
#     117             stream = self._helper.skip_lines(file)
#     118             stream = self._helper.strip_newline(stream)
#
# /opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/_typing.py in wrap_generator(*args, **kwargs)
#     364             try:
#     365                 with context():
# --> 366                     response = gen.send(None)
#     367                 while True:
#     368                     request = yield response
#
# /opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/datapipes/iter/fileopener.py in __iter__(self)
#      58     # a subtype would cause mypy error.
#      59     def __iter__(self):
# ---> 60         yield from get_file_binaries_from_pathnames(self.datapipe, self.mode, self.encoding)
#      61
#      62     def __len__(self):
#
# /opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/datapipes/utils/common.py in get_file_binaries_from_pathnames(pathnames, mode, encoding)
#      83         mode = 'r' + mode
#      84
# ---> 85     for pathname in pathnames:
#      86         if not isinstance(pathname, str):
#      87             raise TypeError("Expected string type for pathname, but got {}"
#
# /opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/_typing.py in wrap_generator(*args, **kwargs)
#     364             try:
#     365                 with context():
# --> 366                     response = gen.send(None)
#     367                 while True:
#     368                     request = yield response
#
# /opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/datapipes/iter/combining.py in __iter__(self)
#      44     def __iter__(self) -> Iterator:
#      45         for dp in self.datapipes:
# ---> 46             for data in dp:
#      47                 yield data
#      48
#
# /opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/_typing.py in wrap_generator(*args, **kwargs)
#     364             try:
#     365                 with context():
# --> 366                     response = gen.send(None)
#     367                 while True:
#     368                     request = yield response
#
# /opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/datapipes/iter/filelister.py in __iter__(self)
#      49
#      50     def __iter__(self) -> Iterator[str] :
# ---> 51         for path in self.datapipe:
#      52             yield from get_file_pathnames_from_root(path, self.masks, self.recursive, self.abspath, self.non_deterministic)
#      53
#
# /opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/_typing.py in wrap_generator(*args, **kwargs)
#     364             try:
#     365                 with context():
# --> 366                     response = gen.send(None)
#     367                 while True:
#     368                     request = yield response
#
# /opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/datapipes/iter/grouping.py in __iter__(self)
#     138
#     139     def __iter__(self):
# --> 140         for element in self.datapipe:
#     141             for i in self._dive(element, unbatch_level=self.unbatch_level):
#     142                 yield i
#
# /opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/_typing.py in wrap_generator(*args, **kwargs)
#     364             try:
#     365                 with context():
# --> 366                     response = gen.send(None)
#     367                 while True:
#     368                     request = yield response
#
# /opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/datapipes/iter/callable.py in __iter__(self)
#     110
#     111     def __iter__(self) -> Iterator[T_co]:
# --> 112         for data in self.datapipe:
#     113             yield self._apply_fn(data)
#     114
#
# /opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/_typing.py in __next__(self)
#     354         def __next__(self):
#     355             with context():
# --> 356                 return next(self.iterator)
#     357
#     358     func = namespace['__iter__']
#
# /opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/datapipes/iter/combining.py in get_generator_by_instance(self, instance_id)
#     188
#     189     def get_generator_by_instance(self, instance_id: int):
# --> 190         yield from self.main_datapipe.get_next_element_by_instance(self.instance_id)
#     191
#     192
#
# /opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/datapipes/iter/combining.py in get_next_element_by_instance(self, instance_id)
#     299             else:
#     300                 try:
# --> 301                     yield self._find_next(instance_id)
#     302                 except StopIteration:
#     303                     stop = True
#
# /opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/datapipes/iter/combining.py in _find_next(self, instance_id)
#     273                     "_datapipe_iterator has not been set, likely because this private method is called directly "
#     274                     "without invoking get_next_element_by_instance() first.")
# --> 275             value = next(self._datapipe_iterator)
#     276             classification = self.classifier_fn(value)
#     277             if classification is None and self.drop_none:
#
# /opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/_typing.py in wrap_generator(*args, **kwargs)
#     364             try:
#     365                 with context():
# --> 366                     response = gen.send(None)
#     367                 while True:
#     368                     request = yield response
#
# /opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/datapipes/iter/combining.py in __iter__(self)
#      44     def __iter__(self) -> Iterator:
#      45         for dp in self.datapipes:
# ---> 46             for data in dp:
#      47                 yield data
#      48
#
# /opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/_typing.py in wrap_generator(*args, **kwargs)
#     364             try:
#     365                 with context():
# --> 366                     response = gen.send(None)
#     367                 while True:
#     368                     request = yield response
#
# /opt/anaconda3/lib/python3.8/site-packages/torchdata/datapipes/iter/util/saver.py in __iter__(self)
#      46
#      47     def __iter__(self) -> Iterator[str]:
# ---> 48         for filepath, data in self.source_datapipe:
#      49             if self.fn is not None:
#      50                 filepath = self.fn(filepath)
#
# /opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/_typing.py in wrap_generator(*args, **kwargs)
#     364             try:
#     365                 with context():
# --> 366                     response = gen.send(None)
#     367                 while True:
#     368                     request = yield response
#
# /opt/anaconda3/lib/python3.8/site-packages/torchdata/datapipes/iter/util/hashchecker.py in __iter__(self)
#      60
#      61     def __iter__(self) -> Iterator[Tuple[str, StreamWrapper]]:
# ---> 62         for file_name, data in self.source_datapipe:
#      63             if self.hash_type == "sha256":
#      64                 hash_func = hashlib.sha256()
#
# /opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/_typing.py in wrap_generator(*args, **kwargs)
#     364             try:
#     365                 with context():
# --> 366                     response = gen.send(None)
#     367                 while True:
#     368                     request = yield response
#
# /opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/datapipes/iter/callable.py in __iter__(self)
#     110
#     111     def __iter__(self) -> Iterator[T_co]:
# --> 112         for data in self.datapipe:
#     113             yield self._apply_fn(data)
#     114
#
# /opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/_typing.py in wrap_generator(*args, **kwargs)
#     364             try:
#     365                 with context():
# --> 366                     response = gen.send(None)
#     367                 while True:
#     368                     request = yield response
#
# /opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/datapipes/iter/callable.py in __iter__(self)
#     111     def __iter__(self) -> Iterator[T_co]:
#     112         for data in self.datapipe:
# --> 113             yield self._apply_fn(data)
#     114
#     115     def __len__(self) -> int:
#
# /opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/datapipes/iter/callable.py in _apply_fn(self, data)
#      84             res = self.fn(*args)
#      85         else:
# ---> 86             res = self.fn(data[self.input_col])
#      87
#      88         # Copy tuple to list and run in-place modification because tuple is immutable.
#
# /opt/anaconda3/lib/python3.8/site-packages/torchdata/datapipes/iter/util/cacheholder.py in _read_bytes(fd)
#     221
#     222 def _read_bytes(fd):
# --> 223     return b"".join(fd)
#     224
#     225
#
# /opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/datapipes/utils/common.py in __iter__(self)
#     137
#     138     def __iter__(self):
# --> 139         for line in self.file_obj:
#     140             yield line
#     141
#
# /opt/anaconda3/lib/python3.8/site-packages/urllib3/response.py in __iter__(self)
#     805     def __iter__(self):
#     806         buffer = []
# --> 807         for chunk in self.stream(decode_content=True):
#     808             if b"\n" in chunk:
#     809                 chunk = chunk.split(b"\n")
#
# /opt/anaconda3/lib/python3.8/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     573         else:
#     574             while not is_fp_closed(self._fp):
# --> 575                 data = self.read(amt=amt, decode_content=decode_content)
#     576
#     577                 if data:
#
# /opt/anaconda3/lib/python3.8/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     516             else:
#     517                 cache_content = False
# --> 518                 data = self._fp.read(amt) if not fp_closed else b""
#     519                 if (
#     520                     amt != 0 and not data
#
# /opt/anaconda3/lib/python3.8/http/client.py in read(self, amt)
#     456             # Amount is given, implement using readinto
#     457             b = bytearray(amt)
# --> 458             n = self.readinto(b)
#     459             return memoryview(b)[:n].tobytes()
#     460         else:
#
# /opt/anaconda3/lib/python3.8/http/client.py in readinto(self, b)
#     500         # connection, and the user is reading more bytes than will be provided
#     501         # (for example, reading in 1k chunks)
# --> 502         n = self.fp.readinto(b)
#     503         if not n and b:
#     504             # Ideally, we would raise IncompleteRead if the content-length
#
# /opt/anaconda3/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# KeyboardInterrupt:
